# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import IPython.display as ipd

import os
import json
import math
import torch
from torch import nn
import math
import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import DataLoader

import commons
import utils
from data_utils import TextAudioLoader, TextAudioCollate, TextAudioSpeakerLoader, TextAudioSpeakerCollate
from models import SynthesizerTrn
from text.symbols import symbols
from text import text_to_sequence
import numpy as np
from text.symbols import symbols, IMM, to_pinlv_list


cutor = IMM()
# Mappings from symbol to numeric ID and vice versa:
_symbol_to_id = {s: i for i, s in enumerate(symbols)}
from scipy.io.wavfile import write




def chinese_cleaners1(text):
    from pypinyin import Style, pinyin

    phones = [phone[0] for phone in pinyin(text, style=Style.TONE3)]
    return ' '.join(phones)


pinyin2pinlv_dict = np.load(r'D:\project\try\pinyin2pinlv\pinyin2pinlv_dict.npy', allow_pickle=True).item()


def txt2seq(text):
    cn_pinying = chinese_cleaners1(text)
    print(cn_pinying)
    clean_text = to_pinlv_list(cn_pinying)
    print(clean_text)
    sequence = [_symbol_to_id[symbol] for symbol in clean_text]
    return sequence


def get_text(text, hps):
    # text_norm = text_to_sequence(text, hps.data.text_cleaners)
    text_norm = txt2seq(text)
    if hps.data.add_blank:
        text_norm = commons.intersperse(text_norm, 0)
    print(text_norm)
    text_norm = torch.LongTensor(text_norm)
    return text_norm

hps = utils.get_hparams_from_file("./logs/a100_pinlv_token/config.json")

net_g = SynthesizerTrn(
    len(symbols),
    hps.data.filter_length // 2 + 1,
    hps.train.segment_size // hps.data.hop_length,
    **hps.model).cpu()
_ = net_g.eval()

_ = utils.load_checkpoint("./logs/a100_pinlv_token/G_142000.pth", net_g, None)

# %%
# stn_tst = get_text("我是中国人，微软小冰在苏州，我在做变声器项目。", hps)
stn_tst = get_text('而且口红的外形上还有流苏，它也是爱情的一个象征，是恋人之间的一种信物。这种感觉把流苏赠送给心爱的人，就代表了两个人相守到老的决心。', hps)
#stn_tst = get_text('送完，爱人还可以送姐妹直播间，还有没有想送礼的？在评论区打出来让主播看看还有谁没有送礼啊。', hps)
#stn_tst = get_text('如果有一天，我能够对我们的公共利益有所贡献，我就会认为自己是世界上最幸福的人了。', hps)
with torch.no_grad():
    x_tst = stn_tst.cpu().unsqueeze(0)
    x_tst_lengths = torch.LongTensor([stn_tst.size(0)]).cpu()
    audio = net_g.infer(x_tst, x_tst_lengths, noise_scale=.667, noise_scale_w=0.8, length_scale=1)[0][0,0].data.cpu().float().numpy()
    #audio = net_g.infer(x_tst, x_tst_lengths, noise_scale=.667, noise_scale_w=0.2, length_scale=1.2)[0][0,0].data.cpu().float().numpy()
print(audio)
# audio.export('./0.wav', format='wav')
print(type(audio))
print(audio.shape)
print(ipd.Audio(audio, rate=hps.data.sampling_rate, normalize=False))
ipd.display(ipd.Audio(audio, rate=hps.data.sampling_rate, normalize=False))
from scipy.io.wavfile import write
scaled = np.int32(audio * 2147483648)  #audio是numpy -1到1之间。
write('test.wav', 22050, scaled)
# Out:
# er2 qie3 kou3 hong2 de wai4 xing2 shang4 hai2 you3 liu2 su1 ， ta1 ye3 shi4 ai4 qing2 de yi2 ge4 xiang4 zheng1 ， shi4 lian4 ren2 zhi1 jian1 de yi1 zhong3 xin4 wu4 。 zhe4 zhong3 gan3 jue2 ba3 liu2 su1 zeng4 song4 gei3 xin1 ai4 de ren2 ， jiu4 dai4 biao3 le liang3 ge4 ren2 xiang1 shou3 dao4 lao3 de jue2 xin1 。
# ['ge', 'er_l', 'er_h', ' ', 'qi', 'eh_l', 'eh_l', ' ', 'k', 'o_l', 'u_l', ' ', 'hu', 'u_l', 'ng_h', ' ', 'd', 'el_m', 'el_m', ' ', 'wu', 'a_h', 'eh_l', ' ', 'xi', 'el_l', 'ng_h', ' ', 'sh', 'aa_h', 'ng_l', ' ', 'h', 'a_l', 'eh_h', ' ', 'yi', 'o_l', 'u_l', ' ', 'li', 'o_l', 'u_h', ' ', 'su', 'u_h', 'u_h', ' ', '，', ' ', 't', 'a_h', 'a_h', ' ', 'yi', 'eh_l', 'eh_l', ' ', 'sh', 'ib_h', 'ib_l', ' ', 'ga', 'a_h', 'eh_l', ' ', 'qi', 'el_l', 'ng_h', ' ', 'd', 'el_m', 'el_m', ' ', 'yi', 'i_l', 'i_h', ' ', 'g', 'el_h', 'el_l', ' ', 'xi', 'aa_h', 'ng_l', ' ', 'zh', 'el_h', 'ng_h', ' ', '，', ' ', 'sh', 'ib_h', 'ib_l', ' ', 'li', 'a_h', 'nn_l', ' ', 'r', 'el_l', 'nn_h', ' ', 'zh', 'ib_h', 'ib_h', ' ', 'ji', 'a_h', 'nn_h', ' ', 'd', 'el_m', 'el_m', ' ', 'yi', 'i_h', 'i_h', ' ', 'zhu', 'u_l', 'ng_l', ' ', 'xi', 'i_h', 'nn_l', ' ', 'wu', 'u_h', 'u_l', ' ', '。', ' ', 'zh', 'el_h', 'el_l', ' ', 'zhu', 'u_l', 'ng_l', ' ', 'g', 'a_l', 'nn_l', ' ', 'jv', 'eh_l', 'eh_h', ' ', 'b', 'a_l', 'a_l', ' ', 'li', 'o_l', 'u_h', ' ', 'su', 'u_h', 'u_h', ' ', 'z', 'el_h', 'ng_l', ' ', 'su', 'u_h', 'ng_l', ' ', 'g', 'eh_l', 'i_l', ' ', 'xi', 'i_h', 'nn_h', ' ', 'ga', 'a_h', 'eh_l', ' ', 'd', 'el_m', 'el_m', ' ', 'r', 'el_l', 'nn_h', ' ', '，', ' ', 'ji', 'o_h', 'u_l', ' ', 'd', 'a_h', 'eh_l', ' ', 'bi', 'aa_l', 'o_l', ' ', 'l', 'el_m', 'el_m', ' ', 'li', 'aa_l', 'ng_l', ' ', 'g', 'el_h', 'el_l', ' ', 'r', 'el_l', 'nn_h', ' ', 'xi', 'aa_h', 'ng_h', ' ', 'sh', 'o_l', 'u_l', ' ', 'd', 'aa_h', 'o_l', ' ', 'l', 'aa_l', 'o_l', ' ', 'd', 'el_m', 'el_m', ' ', 'jv', 'eh_l', 'eh_h', ' ', 'xi', 'i_h', 'nn_h', ' ', '。']
# [0, 158, 0, 136, 0, 80, 0, 13, 0, 160, 0, 78, 0, 78, 0, 13, 0, 50, 0, 162, 0, 91, 0, 13, 0, 108, 0, 91, 0, 143, 0, 13, 0, 43, 0, 88, 0, 88, 0, 13, 0, 145, 0, 85, 0, 78, 0, 13, 0, 122, 0, 109, 0, 143, 0, 13, 0, 128, 0, 94, 0, 165, 0, 13, 0, 47, 0, 120, 0, 169, 0, 13, 0, 139, 0, 162, 0, 91, 0, 13, 0, 125, 0, 162, 0, 123, 0, 13, 0, 102, 0, 123, 0, 123, 0, 13, 0, 3, 0, 13, 0, 59, 0, 85, 0, 85, 0, 13, 0, 139, 0, 78, 0, 78, 0, 13, 0, 128, 0, 96, 0, 106, 0, 13, 0, 148, 0, 85, 0, 78, 0, 13, 0, 160, 0, 109, 0, 143, 0, 13, 0, 43, 0, 88, 0, 88, 0, 13, 0, 139, 0, 161, 0, 164, 0, 13, 0, 46, 0, 121, 0, 109, 0, 13, 0, 122, 0, 94, 0, 165, 0, 13, 0, 155, 0, 121, 0, 143, 0, 13, 0, 3, 0, 13, 0, 128, 0, 96, 0, 106, 0, 13, 0, 125, 0, 85, 0, 116, 0, 13, 0, 57, 0, 109, 0, 133, 0, 13, 0, 155, 0, 96, 0, 96, 0, 13, 0, 172, 0, 85, 0, 133, 0, 13, 0, 43, 0, 88, 0, 88, 0, 13, 0, 139, 0, 164, 0, 164, 0, 13, 0, 154, 0, 91, 0, 165, 0, 13, 0, 122, 0, 164, 0, 116, 0, 13, 0, 145, 0, 123, 0, 91, 0, 13, 0, 4, 0, 13, 0, 155, 0, 121, 0, 109, 0, 13, 0, 154, 0, 91, 0, 165, 0, 13, 0, 46, 0, 120, 0, 116, 0, 13, 0, 95, 0, 78, 0, 169, 0, 13, 0, 41, 0, 120, 0, 120, 0, 13, 0, 125, 0, 162, 0, 123, 0, 13, 0, 102, 0, 123, 0, 123, 0, 13, 0, 65, 0, 121, 0, 165, 0, 13, 0, 102, 0, 123, 0, 165, 0, 13, 0, 46, 0, 78, 0, 161, 0, 13, 0, 122, 0, 164, 0, 133, 0, 13, 0, 148, 0, 85, 0, 78, 0, 13, 0, 43, 0, 88, 0, 88, 0, 13, 0, 57, 0, 109, 0, 133, 0, 13, 0, 3, 0, 13, 0, 172, 0, 134, 0, 91, 0, 13, 0, 43, 0, 85, 0, 78, 0, 13, 0, 137, 0, 113, 0, 162, 0, 13, 0, 51, 0, 88, 0, 88, 0, 13, 0, 125, 0, 113, 0, 165, 0, 13, 0, 46, 0, 121, 0, 109, 0, 13, 0, 57, 0, 109, 0, 133, 0, 13, 0, 122, 0, 94, 0, 143, 0, 13, 0, 128, 0, 162, 0, 91, 0, 13, 0, 43, 0, 94, 0, 162, 0, 13, 0, 51, 0, 113, 0, 162, 0, 13, 0, 43, 0, 88, 0, 88, 0, 13, 0, 95, 0, 78, 0, 169, 0, 13, 0, 122, 0, 164, 0, 133, 0, 13, 0, 4, 0]
# [-4.0583996e-05  1.8979670e-04  2.5605469e-04 ...  1.1537721e-03
#   1.1715079e-03  1.1550534e-03]
# <class 'numpy.ndarray'>
# (274432,)
# <IPython.lib.display.Audio object>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
