# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import IPython.display as ipd

import os
import json
import math
import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import DataLoader

import commons
import utils
from data_utils import TextAudioLoader, TextAudioCollate, TextAudioSpeakerLoader, TextAudioSpeakerCollate
from models import SynthesizerTrn
from text.symbols import symbols
from text import text_to_sequence

from scipy.io.wavfile import write


def get_text(text, hps):
    text_norm = text_to_sequence(text, hps.data.text_cleaners)
    if hps.data.add_blank:
        text_norm = commons.intersperse(text_norm, 0)
    text_norm = torch.LongTensor(text_norm)
    return text_norm

# %%
hps = utils.get_hparams_from_file("./configs/ljs_base.json")

# %%
net_g = SynthesizerTrn(
    len(symbols),
    hps.data.filter_length // 2 + 1,
    hps.train.segment_size // hps.data.hop_length,
    **hps.model).cuda()
_ = net_g.eval()

_ = utils.load_checkpoint("pretrained_ljs.pth", net_g, None)

# %%
net_g = SynthesizerTrn(
    len(symbols),
    hps.data.filter_length // 2 + 1,
    hps.train.segment_size // hps.data.hop_length,
    **hps.model).cpu()
_ = net_g.eval()

_ = utils.load_checkpoint("pretrained_ljs.pth", net_g, None)

# %%
ttt = 'Indeed, if we spend a lot of space describing second novelty, we should compare it with other PEs, although there is no PE like our proposed PE before. So, we need to focus the paper on MCS-RSC and re-organize the paper in the future. On the other hand, we should include some literature reviews on MCS, graph matching and subgraph matching methods in the Section. related work. Regarding the fairness of the previous approach, we performed a hyperparameter search on the validation set for all other previous baseline models, which made the results of the previous method better and fairer.'
stn_tst = get_text(ttt, hps)
with torch.no_grad():
    x_tst = stn_tst.cpu().unsqueeze(0)
    x_tst_lengths = torch.LongTensor([stn_tst.size(0)]).cpu()
    audio = net_g.infer(x_tst, x_tst_lengths, noise_scale=.667, noise_scale_w=0.8, length_scale=1)[0][0,0].data.cpu().float().numpy()
ipd.display(ipd.Audio(audio, rate=hps.data.sampling_rate, normalize=False))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ttt = 'This is a reminder Email about the overdue book(s) in your account. Please return the book(s) as soon as possible to the circulation desk on library 3rd floor or use the self-returning machine on the 1st, 4th and 8th floor of the Library. Please kindly note that according to the Library regulation on books circulation, the overdue items will be fined as we encourage timely return of books for public good. Meanwhile, you may reduce the fines using your Library reward points. For more information about Library reward points please go to'
stn_tst = get_text(ttt, hps)
with torch.no_grad():
    x_tst = stn_tst.cuda().unsqueeze(0)
    x_tst_lengths = torch.LongTensor([stn_tst.size(0)]).cuda()
    audio = net_g.infer(x_tst, x_tst_lengths, noise_scale=.667, noise_scale_w=0.8, length_scale=1)[0][0,0].data.cpu().float().numpy()
ipd.display(ipd.Audio(audio, rate=hps.data.sampling_rate, normalize=False))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17820\2156647345.py in <module>
#       4     x_tst = stn_tst.cuda().unsqueeze(0)
#       5     x_tst_lengths = torch.LongTensor([stn_tst.size(0)]).cuda()
# ----> 6     audio = net_g.infer(x_tst, x_tst_lengths, noise_scale=.667, noise_scale_w=0.8, length_scale=1)[0][0,0].data.cpu().float().numpy()
#       7 ipd.display(ipd.Audio(audio, rate=hps.data.sampling_rate, normalize=False))
#
# D:\project\vits-main\models.py in infer(self, x, x_lengths, sid, noise_scale, length_scale, noise_scale_w, max_len)
#     498
#     499   def infer(self, x, x_lengths, sid=None, noise_scale=1, length_scale=1, noise_scale_w=1., max_len=None):
# --> 500     x, m_p, logs_p, x_mask = self.enc_p(x, x_lengths)
#     501     if self.n_speakers > 0:
#     502       g = self.emb_g(sid).unsqueeze(-1) # [b, h, 1]
#
# ...
